# %%
#### https://www.kaggle.com/dikshabhati2002/let-s-classify-audio-ml-dl

import matplotlib.pyplot as plt
import librosa
import librosa.display
import IPython.display as ipd
from scipy.io import wavfile as wav
import pandas as pd
import math
import os
import numpy as np
import seaborn as sns
import json


from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier, XGBRFClassifier
import catboost as cb

from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ReduceLROnPlateau,EarlyStopping,ModelCheckpoint,LearningRateScheduler
import tensorflow.keras as keras
from tensorflow.keras import optimizers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import *

# %%
sample_rate = 22050
sr = 22050     # sample rate. based on Nyquist frequency, we only care about frequencies up to 10kHz therefor the sample rate will only perserve those frequencies 
n_fft = 2048
hop_length = 512
duration = 29 # length of song to be used (in seconds) 
n_mels=128
samples_per_track = sr * duration
n_mfcc = 40

json_path = r"data.json"

# %%
# set a path pointing to folder with data
filepath = '/Users/stephen/Flatiron/Phase4/MIR/Data/genres_original'
# folders contain different genres (classes), lets list all the genres
print(list(os.listdir(f'{filepath}/')))
# Out:
# ['pop', 'metal', 'disco', 'blues', 'reggae', 'classical', 'rock', '.gitattributes', 'hiphop', 'country', 'jazz']

# %%
# load csv with metadata
df = pd.read_csv('/Users/stephen/Flatiron/Phase4/MIR/Data/features_3_sec.csv')
df.head()
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1  blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2  blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3  blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4  blues.00000.4.wav   66149          0.335579         0.088129  0.143289
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.003521             1773.065032          167541.630869
# 1  0.001450             1816.693777           90525.690866
# 2  0.004620             1788.539719          111407.437613
# 3  0.002448             1655.289045          111952.284517
# 4  0.001701             1630.656199           79667.267654
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              1972.744388           117335.771563  ...   39.687145
# 1              2010.051501            65671.875673  ...   64.748276
# 2              2084.565132            75124.921716  ...   67.336563
# 3              1960.039988            82913.639269  ...   47.739452
# 4              1948.503884            60204.020268  ...   30.336359
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0    -3.241280   36.488243     0.722209   38.099152    -5.050335   33.618073
# 1    -6.055294   40.677654     0.159015   51.264091    -2.837699   97.030830
# 2    -1.768610   28.348579     2.378768   45.717648    -1.938424   53.050835
# 3    -3.841155   28.337118     1.218588   34.770935    -3.580352   50.836224
# 4     0.664582   45.880913     1.689446   51.363583    -3.392489   26.738789
#
#    mfcc20_mean  mfcc20_var  label
# 0    -0.243027   43.771767  blues
# 1     5.784063   59.943081  blues
# 2     2.517375   33.105122  blues
# 3     3.630866   32.023678  blues
# 4     0.536961   29.146694  blues
#
# [5 rows x 60 columns]

# %%
df.shape
# Out:
# (9990, 60)

# %%
df
# Out:
#                filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0     blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1     blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2     blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3     blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4     blues.00000.4.wav   66149          0.335579         0.088129  0.143289
# ...                 ...     ...               ...              ...       ...
# 9985   rock.00099.5.wav   66149          0.349126         0.080515  0.050019
# 9986   rock.00099.6.wav   66149          0.372564         0.082626  0.057897
# 9987   rock.00099.7.wav   66149          0.347481         0.089019  0.052403
# 9988   rock.00099.8.wav   66149          0.387527         0.084815  0.066430
# 9989   rock.00099.9.wav   66149          0.369293         0.086759  0.050524
#
#        rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0     0.003521             1773.065032          167541.630869
# 1     0.001450             1816.693777           90525.690866
# 2     0.004620             1788.539719          111407.437613
# 3     0.002448             1655.289045          111952.284517
# 4     0.001701             1630.656199           79667.267654
# ...        ...                     ...                    ...
# 9985  0.000097             1499.083005          164266.886443
# 9986  0.000088             1847.965128          281054.935973
# 9987  0.000701             1346.157659          662956.246325
# 9988  0.000320             2084.515327          203891.039161
# 9989  0.000067             1634.330126          411429.169769
#
#       spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0                 1972.744388           117335.771563  ...   39.687145
# 1                 2010.051501            65671.875673  ...   64.748276
# 2                 2084.565132            75124.921716  ...   67.336563
# 3                 1960.039988            82913.639269  ...   47.739452
# 4                 1948.503884            60204.020268  ...   30.336359
# ...                       ...                     ...  ...         ...
# 9985              1718.707215            85931.574523  ...   42.485981
# 9986              1906.468492            99727.037054  ...   32.415203
# 9987              1561.859087           138762.841945  ...   78.228149
# 9988              2018.366254            22860.992562  ...   28.323744
# 9989              1867.422378           119722.211518  ...   38.801735
#
#       mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  \
# 0       -3.241280   36.488243     0.722209   38.099152    -5.050335
# 1       -6.055294   40.677654     0.159015   51.264091    -2.837699
# 2       -1.768610   28.348579     2.378768   45.717648    -1.938424
# 3       -3.841155   28.337118     1.218588   34.770935    -3.580352
# 4        0.664582   45.880913     1.689446   51.363583    -3.392489
# ...           ...         ...          ...         ...          ...
# 9985    -9.094270   38.326839    -4.246976   31.049839    -5.625813
# 9986   -12.375726   66.418587    -3.081278   54.414265   -11.960546
# 9987    -2.524483   21.778994     4.809936   25.980829     1.775686
# 9988    -5.363541   17.209942     6.462601   21.442928     2.354765
# 9989   -11.598399   58.983097    -0.178517   55.761299    -6.903252
#
#       mfcc19_var  mfcc20_mean  mfcc20_var  label
# 0      33.618073    -0.243027   43.771767  blues
# 1      97.030830     5.784063   59.943081  blues
# 2      53.050835     2.517375   33.105122  blues
# 3      50.836224     3.630866   32.023678  blues
# 4      26.738789     0.536961   29.146694  blues
# ...          ...          ...         ...    ...
# 9985   48.804092     1.818823   38.966969   rock
# 9986   63.452255     0.428857   18.697033   rock
# 9987   48.582378    -0.299545   41.586990   rock
# 9988   24.843613     0.675824   12.787750   rock
# 9989   39.485901    -3.412534   31.727489   rock
#
# [9990 rows x 60 columns]

# %%
df['label'].value_counts()
# Out:
# blues        1000
# jazz         1000
# metal        1000
# pop          1000
# reggae       1000
# disco         999
# classical     998
# hiphop        998
# rock          998
# country       997
# Name: label, dtype: int64

# %%
x = df[["label", "tempo"]]

fig, ax = plt.subplots(figsize=(16, 8));
sns.boxplot(x = "label", y = "tempo", data = x, palette = 'husl');

plt.title('BPM Boxplot for Genres', fontsize = 20)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 10);
plt.xlabel("Genre", fontsize = 15)
plt.ylabel("BPM", fontsize = 15)
plt.savefig("BPM_Boxplot.png")

# %%
def save_mfcc(dataset_path, json_path, n_mfcc=13, n_fft=2048,
             hop_length=512, num_segments=5):
    # Data storage dictionary
    data = {
        "mapping": [],
        "mfcc": [],
        "labels": [],
    }
    samples_ps = int(samples_per_track/num_segments) # ps = per segment
    expected_vects_ps = math.ceil(samples_ps/hop_length)
    
    # loop through all the genres
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):
        # ensuring not at root
        if dirpath is not dataset_path:
            # save the semantic label
            dirpath_comp = dirpath.split("/")
            semantic_label = dirpath_comp[-1]
            data["mapping"].append(semantic_label)
            print(f"Processing: {semantic_label}")
            
            # process files for specific genre
            for f in filenames:
                if(f==str("jazz.00054.wav")):
                    # As librosa only read files <1Mb
                    continue
                else:
                    # load audio file
                    file_path = os.path.join(dirpath, f)
                    signal,sr = librosa.load(file_path,sr=sample_rate)
                    for s in range(num_segments):
                        start_sample = samples_ps * s
                        finish_sample = start_sample + samples_ps

                        mfcc = librosa.feature.mfcc(signal[start_sample:finish_sample],
                                                    sr = sr,
                                                    n_fft = n_fft,
                                                    n_mfcc = n_mfcc,
                                                    hop_length = hop_length)

                        mfcc = mfcc.T

                        # store mfcc if it has expected length 
                        if len(mfcc)==expected_vects_ps:
                            data["mfcc"].append(mfcc.tolist())
                            data["labels"].append(i-1)
                            print(f"{file_path}, segment: {s+1}")

    with open(json_path,"w") as f:
        json.dump(data,f,indent=4)

# %%
save_mfcc(filepath,json_path,num_segments=10)
#clear_output()
# Out:
# Processing: pop
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00027.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00027.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00027.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00027.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00027.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00027.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00027.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00027.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00027.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00027.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00033.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00033.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00033.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00033.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00033.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00033.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00033.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00033.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00033.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00033.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00032.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00032.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00032.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00032.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00032.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00032.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00032.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00032.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00032.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00032.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00026.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00026.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00026.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00026.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00026.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00026.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00026.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00026.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00026.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00026.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00030.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00030.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00030.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00030.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00030.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00030.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00030.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00030.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00030.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00030.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00024.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00024.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00024.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00024.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00024.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00024.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00024.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00024.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00024.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00024.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00018.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00018.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00018.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00018.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00018.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00018.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00018.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00018.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00018.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00018.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00019.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00019.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00019.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00019.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00019.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00019.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00019.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00019.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00019.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00019.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00025.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00025.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00025.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00025.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00025.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00025.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00025.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00025.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00025.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00025.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00031.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00031.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00031.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00031.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00031.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00031.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00031.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00031.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00031.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00031.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00009.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00009.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00009.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00009.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00009.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00009.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00009.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00009.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00009.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00009.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00035.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00035.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00035.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00035.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00035.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00035.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00035.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00035.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00035.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00035.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00021.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00021.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00021.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00021.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00021.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00021.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00021.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00021.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00021.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00021.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00020.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00020.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00020.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00020.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00020.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00020.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00020.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00020.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00020.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00020.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00034.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00034.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00034.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00034.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00034.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00034.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00034.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00034.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00034.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00034.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00008.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00008.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00008.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00008.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00008.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00008.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00008.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00008.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00008.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00008.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00022.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00022.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00022.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00022.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00022.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00022.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00022.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00022.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00022.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00022.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00036.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00036.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00036.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00036.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00036.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00036.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00036.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00036.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00036.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00036.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00037.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00037.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00037.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00037.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00037.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00037.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00037.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00037.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00037.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00037.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00023.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00023.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00023.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00023.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00023.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00023.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00023.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00023.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00023.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00023.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00044.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00044.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00044.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00044.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00044.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00044.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00044.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00044.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00044.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00044.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00050.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00050.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00050.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00050.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00050.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00050.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00050.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00050.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00050.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00050.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00078.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00078.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00078.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00078.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00078.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00078.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00078.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00078.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00078.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00078.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00087.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00087.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00087.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00087.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00087.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00087.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00087.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00087.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00087.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00087.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00093.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00093.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00093.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00093.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00093.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00093.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00093.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00093.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00093.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00093.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00092.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00092.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00092.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00092.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00092.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00092.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00092.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00092.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00092.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00092.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00086.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00086.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00086.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00086.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00086.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00086.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00086.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00086.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00086.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00086.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00079.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00079.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00079.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00079.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00079.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00079.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00079.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00079.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00079.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00079.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00051.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00051.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00051.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00051.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00051.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00051.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00051.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00051.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00051.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00051.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00045.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00045.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00045.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00045.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00045.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00045.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00045.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00045.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00045.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00045.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00053.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00053.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00053.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00053.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00053.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00053.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00053.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00053.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00053.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00053.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00047.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00047.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00047.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00047.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00047.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00047.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00047.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00047.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00047.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00047.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00090.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00090.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00090.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00090.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00090.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00090.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00090.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00090.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00090.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00090.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00084.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00084.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00084.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00084.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00084.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00084.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00084.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00084.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00084.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00084.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00085.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00085.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00085.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00085.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00085.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00085.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00085.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00085.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00085.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00085.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00091.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00091.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00091.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00091.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00091.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00091.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00091.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00091.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00091.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00091.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00046.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00046.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00046.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00046.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00046.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00046.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00046.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00046.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00046.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00046.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00052.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00052.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00052.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00052.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00052.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00052.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00052.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00052.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00052.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00052.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00056.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00056.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00056.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00056.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00056.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00056.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00056.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00056.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00056.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00056.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00042.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00042.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00042.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00042.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00042.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00042.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00042.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00042.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00042.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00042.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00095.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00095.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00095.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00095.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00095.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00095.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00095.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00095.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00095.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00095.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00081.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00081.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00081.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00081.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00081.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00081.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00081.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00081.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00081.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00081.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00080.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00080.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00080.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00080.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00080.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00080.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00080.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00080.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00080.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00080.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00094.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00094.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00094.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00094.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00094.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00094.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00094.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00094.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00094.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00094.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00043.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00043.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00043.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00043.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00043.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00043.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00043.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00043.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00043.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00043.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00057.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00057.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00057.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00057.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00057.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00057.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00057.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00057.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00057.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00057.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00069.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00069.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00069.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00069.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00069.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00069.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00069.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00069.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00069.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00069.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00041.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00041.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00041.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00041.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00041.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00041.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00041.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00041.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00041.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00041.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00055.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00055.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00055.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00055.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00055.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00055.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00055.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00055.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00055.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00055.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00082.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00082.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00082.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00082.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00082.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00082.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00082.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00082.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00082.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00082.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00096.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00096.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00096.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00096.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00096.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00096.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00096.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00096.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00096.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00096.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00097.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00097.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00097.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00097.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00097.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00097.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00097.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00097.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00097.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00097.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00083.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00083.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00083.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00083.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00083.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00083.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00083.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00083.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00083.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00083.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00054.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00054.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00054.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00054.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00054.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00054.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00054.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00054.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00054.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00054.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00040.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00040.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00040.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00040.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00040.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00040.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00040.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00040.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00040.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00040.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00068.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00068.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00068.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00068.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00068.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00068.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/pop/pop.00068.wav, segment: 7
# ...
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00023.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00022.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00022.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00022.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00022.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00022.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00022.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00022.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00022.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00022.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00022.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00036.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00036.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00036.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00036.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00036.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00036.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00036.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00036.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00036.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00036.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00020.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00020.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00020.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00020.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00020.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00020.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00020.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00020.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00020.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00020.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00034.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00034.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00034.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00034.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00034.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00034.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00034.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00034.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00034.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00034.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00008.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00008.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00008.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00008.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00008.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00008.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00008.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00008.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00008.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00008.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00009.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00009.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00009.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00009.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00009.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00009.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00009.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00009.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00009.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00009.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00035.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00035.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00035.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00035.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00035.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00035.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00035.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00035.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00035.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00035.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00021.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00021.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00021.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00021.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00021.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00021.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00021.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00021.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00021.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00021.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00019.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00019.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00019.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00019.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00019.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00019.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00019.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00019.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00019.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00019.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00025.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00025.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00025.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00025.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00025.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00025.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00025.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00025.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00025.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00025.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00031.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00031.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00031.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00031.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00031.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00031.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00031.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00031.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00031.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00031.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00030.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00030.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00030.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00030.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00030.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00030.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00030.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00030.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00030.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00030.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00024.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00024.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00024.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00024.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00024.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00024.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00024.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00024.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00024.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00024.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00018.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00018.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00018.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00018.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00018.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00018.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00018.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00018.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00018.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00018.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00032.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00032.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00032.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00032.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00032.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00032.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00032.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00032.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00032.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00032.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00026.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00026.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00026.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00026.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00026.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00026.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00026.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00026.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00026.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00026.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00027.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00027.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00027.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00027.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00027.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00027.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00027.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00027.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00027.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00027.wav, segment: 10
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00033.wav, segment: 1
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00033.wav, segment: 2
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00033.wav, segment: 3
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00033.wav, segment: 4
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00033.wav, segment: 5
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00033.wav, segment: 6
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00033.wav, segment: 7
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00033.wav, segment: 8
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00033.wav, segment: 9
# /Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/jazz/jazz.00033.wav, segment: 10

# %%
# loading in the data 
def load_data(filepath):
    with open(filepath, 'r') as f:
        data = json.load(f)

    # convert list to numpy arrays
    inputs = np.array(data['mfcc'])
    targets = np.array(data['labels'])

    return inputs, targets

# %%
# set up variables 
inputs, targets = load_data(r'/Users/stephen/Flatiron/Phase4/MIR/notebooks/stephen/data.json')
inputs.shape
# Out:
# (9990, 125, 13)

# %%
# splitting the data 
# input_train, input_test, target_train, target_test
X_train, X_test, y_train, y_test = train_test_split(inputs, targets, test_size=0.3)
print(X_train.shape, y_train.shape)
# Out:
# (6993, 125, 13) (6993,)

# %%
model = Sequential()

model.add(Flatten(input_shape=(inputs.shape[1],inputs.shape[2])))
model.add(Dense(512, activation='relu', kernel_regularizer = keras.regularizers.l2(0.001)))
model.add(Dropout(0.3))
model.add(Dense(256, activation='relu', kernel_regularizer = keras.regularizers.l2(0.003)))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu', kernel_regularizer = keras.regularizers.l2(0.01)))
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 1625)              0
#
#  dense (Dense)               (None, 512)               832512
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 982,698
# Trainable params: 982,698
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam = optimizers.Adam(learning_rate=1e-4)

# %%
model.compile(optimizer=adam, 
            loss='sparse_categorical_crossentropy', 
            metrics=['accuracy'])

hist = model.fit(X_train, y_train, 
                validation_data = (X_test, y_test), 
                epochs = 50, 
                batch_size = 16)
# Out:
# Epoch 1/50
# 438/438 [==============================] - 5s 8ms/step - loss: 1.0363 - accuracy: 0.7679 - val_loss: 1.7342 - val_accuracy: 0.5896
# Epoch 2/50
# 438/438 [==============================] - 3s 6ms/step - loss: 0.9873 - accuracy: 0.7778 - val_loss: 1.8082 - val_accuracy: 0.5913
# Epoch 3/50
# 438/438 [==============================] - 3s 7ms/step - loss: 0.9674 - accuracy: 0.7931 - val_loss: 1.7395 - val_accuracy: 0.5979
# Epoch 4/50
# 438/438 [==============================] - 3s 6ms/step - loss: 0.9145 - accuracy: 0.8039 - val_loss: 1.7283 - val_accuracy: 0.5946
# Epoch 5/50
# 438/438 [==============================] - 3s 6ms/step - loss: 0.8947 - accuracy: 0.8087 - val_loss: 1.8442 - val_accuracy: 0.5879
# Epoch 6/50
# 438/438 [==============================] - 3s 7ms/step - loss: 0.9096 - accuracy: 0.8068 - val_loss: 1.7367 - val_accuracy: 0.5869
# Epoch 7/50
# 438/438 [==============================] - 3s 7ms/step - loss: 0.8787 - accuracy: 0.8155 - val_loss: 1.7743 - val_accuracy: 0.5929
# Epoch 8/50
# 438/438 [==============================] - 3s 6ms/step - loss: 0.8839 - accuracy: 0.8108 - val_loss: 1.7560 - val_accuracy: 0.5873
# Epoch 9/50
# 438/438 [==============================] - 3s 7ms/step - loss: 0.8644 - accuracy: 0.8130 - val_loss: 1.6976 - val_accuracy: 0.5979
# Epoch 10/50
# 438/438 [==============================] - 3s 7ms/step - loss: 0.8470 - accuracy: 0.8257 - val_loss: 1.6531 - val_accuracy: 0.5996
# Epoch 11/50
# 438/438 [==============================] - 3s 6ms/step - loss: 0.8468 - accuracy: 0.8250 - val_loss: 1.7184 - val_accuracy: 0.6006
# Epoch 12/50
# 438/438 [==============================] - 3s 7ms/step - loss: 0.8692 - accuracy: 0.8168 - val_loss: 1.7537 - val_accuracy: 0.5989
# Epoch 13/50
# 438/438 [==============================] - 3s 8ms/step - loss: 0.8178 - accuracy: 0.8318 - val_loss: 1.7423 - val_accuracy: 0.5996
# Epoch 14/50
# 438/438 [==============================] - 3s 7ms/step - loss: 0.8197 - accuracy: 0.8327 - val_loss: 1.7480 - val_accuracy: 0.5986
# Epoch 15/50
# 438/438 [==============================] - 3s 7ms/step - loss: 0.8151 - accuracy: 0.8331 - val_loss: 1.7229 - val_accuracy: 0.6023
# Epoch 16/50
# 438/438 [==============================] - 3s 6ms/step - loss: 0.8088 - accuracy: 0.8351 - val_loss: 1.7808 - val_accuracy: 0.5989
# Epoch 17/50
# 438/438 [==============================] - 3s 6ms/step - loss: 0.8071 - accuracy: 0.8348 - val_loss: 1.7175 - val_accuracy: 0.6076
# Epoch 18/50
# 438/438 [==============================] - 3s 7ms/step - loss: 0.7915 - accuracy: 0.8358 - val_loss: 1.7401 - val_accuracy: 0.5989
# Epoch 19/50
# 438/438 [==============================] - 3s 6ms/step - loss: 0.7685 - accuracy: 0.8460 - val_loss: 1.8001 - val_accuracy: 0.6013
# Epoch 20/50
# 438/438 [==============================] - 3s 6ms/step - loss: 0.7659 - accuracy: 0.8474 - val_loss: 1.7232 - val_accuracy: 0.6009
# Epoch 21/50
# 438/438 [==============================] - 3s 8ms/step - loss: 0.7642 - accuracy: 0.8494 - val_loss: 1.6747 - val_accuracy: 0.6033
# Epoch 22/50
# 438/438 [==============================] - 4s 8ms/step - loss: 0.7734 - accuracy: 0.8413 - val_loss: 1.6582 - val_accuracy: 0.6240
# Epoch 23/50
# 438/438 [==============================] - 4s 8ms/step - loss: 0.7518 - accuracy: 0.8529 - val_loss: 1.7161 - val_accuracy: 0.6116
# Epoch 24/50
# 438/438 [==============================] - 3s 6ms/step - loss: 0
# Epoch 49/50
# 438/438 [==============================] - 6s 13ms/step - loss: 0.6436 - accuracy: 0.8787 - val_loss: 1.8057 - val_accuracy: 0.6086
# Epoch 50/50
# 438/438 [==============================] - 4s 10ms/step - loss: 0.6287 - accuracy: 0.8857 - val_loss: 1.7185 - val_accuracy: 0.6193

# %%
def plot_history(hist):
    plt.figure(figsize=(20,15))
    fig, axs = plt.subplots(2)
    # accuracy subplot
    axs[0].plot(hist.history["accuracy"], label="train accuracy")
    axs[0].plot(hist.history["val_accuracy"], label="test accuracy")    
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")
    
    # Error subplot
    axs[1].plot(hist.history["loss"], label="train error")
    axs[1].plot(hist.history["val_loss"], label="test error")    
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")
    
    plt.show()

# %%
plot_history(hist)

# %%
test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
print(f"Test accuracy: {test_accuracy}")
# Out:
# 94/94 [==============================] - 0s 3ms/step - loss: 1.7185 - accuracy: 0.6193
# Test accuracy: 0.6192859411239624

# %%
out = model.predict(X_test)
out.shape
# Out:
# (2997, 10)

# %%
X_test.shape
# Out:
# (2997, 125, 13)

# %%
# CNN

def prepare_dataset(test_size, validation_size):
    X,y = load_data(r"/Users/stephen/Flatiron/Phase4/MIR/notebooks/stephen/data.json")
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = test_size)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = validation_size)
    X_train = X_train[..., np.newaxis]
    X_val = X_val[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
X_train, X_val, X_test, y_train, y_val, y_test = prepare_dataset(0.25, 0.2)

# %%
input_shape = (X_train.shape[1],X_train.shape[2],X_train.shape[3])
print(input_shape)
# Out:
# (125, 13, 1)

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), activation = "relu", input_shape = input_shape))
model.add(MaxPool2D((3, 3), strides=(2, 2), padding="same"))
model.add(BatchNormalization())

model.add(Conv2D(32, (3, 3), activation = "relu"))
model.add(MaxPool2D((3, 3), strides=(2, 2), padding="same"))
model.add(BatchNormalization())

model.add(Conv2D(32, (2, 2), activation = "relu"))
model.add(MaxPool2D((2, 2), strides=(2, 2), padding="same"))
model.add(BatchNormalization())

model.add(Conv2D(16, (1, 1), activation = "relu"))
model.add(MaxPool2D((1, 1), strides=(2, 2), padding="same"))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(10, activation="softmax"))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 123, 11, 64)       640
#
#  max_pooling2d_4 (MaxPooling  (None, 62, 6, 64)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 62, 6, 64)        256
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 60, 4, 32)         18464
#
#  max_pooling2d_5 (MaxPooling  (None, 30, 2, 32)        0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 30, 2, 32)        128
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 29, 1, 32)         4128
#
#  max_pooling2d_6 (MaxPooling  (None, 15, 1, 32)        0
#  2D)
#
#  batch_normalization_6 (Batc  (None, 15, 1, 32)        128
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 15, 1, 16)         528
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 1, 16)         0
#  2D)
#
#  batch_normalization_7 (Batc  (None, 8, 1, 16)         64
#  hNormalization)
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 33,242
# Trainable params: 32,954
# Non-trainable params: 288
# _________________________________________________________________

# %%
model.compile(optimizer=adam,
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

hist = model.fit(X_train, y_train,
                 validation_data = (X_val, y_val),
                 epochs = 40,
                 batch_size = 32)
# Out:
# Epoch 1/40
# 188/188 [==============================] - 12s 59ms/step - loss: 2.1263 - accuracy: 0.2723 - val_loss: 1.8192 - val_accuracy: 0.3676
# Epoch 2/40
# 188/188 [==============================] - 10s 51ms/step - loss: 1.6792 - accuracy: 0.3973 - val_loss: 1.5149 - val_accuracy: 0.4583
# Epoch 3/40
# Epoch 24/40
# 188/188 [==============================] - 10s 55ms/step - loss: 0.8207 - accuracy: 0.7133 - val_loss: 0.9157 - val_accuracy: 0.6778
# Epoch 25/40
# 188/188 [==============================] - 10s 53ms/step - loss: 0.8200 - accuracy: 0.7098 - val_loss: 0.8950 - val_accuracy: 0.6858
# Epoch 26/40
# 188/188 [==============================] - 10s 54ms/step - loss: 0.8060 - accuracy: 0.7172 - val_loss: 0.8919 - val_accuracy: 0.6898
# Epoch 27/40
# 188/188 [==============================] - 10s 54ms/step - loss: 0.7947 - accuracy: 0.7290 - val_loss: 0.8780 - val_accuracy: 0.6985
# Epoch 28/40
# 188/188 [==============================] - 11s 56ms/step - loss: 0.7728 - accuracy: 0.7278 - val_loss: 0.8956 - val_accuracy: 0.6871
# Epoch 29/40
# 188/188 [==============================] - 11s 61ms/step - loss: 0.7529 - accuracy: 0.7357 - val_loss: 0.9214 - val_accuracy: 0.6724
# Epoch 30/40
# 188/188 [==============================] - 11s 58ms/step - loss: 0.7589 - accuracy: 0.7364 - val_loss: 0.9015 - val_accuracy: 0.6871
# Epoch 31/40
# 188/188 [==============================] - 12s 63ms/step - loss: 0.7492 - accuracy: 0.7399 - val_loss: 0.8622 - val_accuracy: 0.6998
# Epoch 32/40
# 188/188 [==============================] - 12s 62ms/step - loss: 0.7314 - accuracy: 0.7459 - val_loss: 0.8923 - val_accuracy: 0.6945
# Epoch 33/40
# 188/188 [==============================] - 11s 61ms/step - loss: 0.7127 - accuracy: 0.7505 - val_loss: 0.9063 - val_accuracy: 0.6758
# Epoch 34/40
# 188/188 [==============================] - 12s 62ms/step - loss: 0.6952 - accuracy: 0.7559 - val_loss: 0.9518 - val_accuracy: 0.6564
# Epoch 35/40
# 188/188 [==============================] - 11s 57ms/step - loss: 0.6857 - accuracy: 0.7597 - val_loss: 0.8407 - val_accuracy: 0.7178
# Epoch 36/40
# 188/188 [==============================] - 10s 53ms/step - loss: 0.6943 - accuracy: 0.7557 - val_loss: 0.8421 - val_accuracy: 0.7065
# Epoch 37/40
# 188/188 [==============================] - 11s 57ms/step - loss: 0.6785 - accuracy: 0.7632 - val_loss: 0.8416 - val_accuracy: 0.7078
# Epoch 38/40
# 188/188 [==============================] - 11s 60ms/step - loss: 0.6661 - accuracy: 0.7676 - val_loss: 0.8585 - val_accuracy: 0.7058
# Epoch 39/40
# 188/188 [==============================] - 11s 60ms/step - loss: 0.6583 - accuracy: 0.7687 - val_loss: 0.8995 - val_accuracy: 0.6931
# Epoch 40/40
# 188/188 [==============================] - 11s 57ms/step - loss: 0.6475 - accuracy: 0.7809 - val_loss: 0.8799 - val_accuracy: 0.6991

# %%
plot_history(hist)

# %%
test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
print(f"Test accuracy: {test_accuracy}")
# Out:
# 79/79 [==============================] - 1s 13ms/step - loss: 0.8254 - accuracy: 0.7262
# Test accuracy: 0.7261809706687927

# %%
def predict(model, X, y):
    X = X[np.newaxis,...]
    prediction = model.predict(X)
    predicted_index = np.argmax(prediction, axis=1)
    print(f"Expected index: {y}, Predicted index: {predicted_index}")

# %%
predict(model, X_test[10], y_test[10])
# Out:
# Expected index: 5, Predicted index: [5]
