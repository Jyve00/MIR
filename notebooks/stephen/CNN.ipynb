# %%
import pandas as pd
import numpy as np 
from pathlib import Path
import librosa
import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline 
from torch.utils.data import DataLoader, Dataset, random_split
import torchaudio

# %%
data_folder = '/Users/stephen/Flatiron/Phase4/MIR/notebooks/stephen/img_data'
df_csv = pd.read_csv('/Users/stephen/Flatiron/Phase4/MIR/Data/features_30_sec.csv')
df_csv.head()
# Out:
#           filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1  blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2  blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3  blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4  blues.00004.wav  661794          0.308526         0.087841  0.091529
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002827             1784.165850          129774.064525
# 1  0.002373             1530.176679          375850.073649
# 2  0.002746             1552.811865          156467.643368
# 3  0.006346             1070.106615          184355.942417
# 4  0.002303             1835.004266          343399.939274
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              2002.449060            85882.761315  ...   52.420910
# ...

# %%
df_csv = df[['filename', 'label']]
df_csv.head()
# Out:
#           filename  label
# 0  blues.00000.wav  blues
# 1  blues.00001.wav  blues
# 2  blues.00002.wav  blues
# 3  blues.00003.wav  blues
# 4  blues.00004.wav  blues

# %%
# file paths

folder_path = '/Users/stephen/Flatiron/Phase4/MIR/Data/genres_original'
files = librosa.util.find_files(folder_path, ext=['wav'], recurse=True)
files = np.asarray(files)
files
# Out:
# array(['/Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/blues/blues.00000.wav',
#        '/Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/blues/blues.00001.wav',
#        '/Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/blues/blues.00002.wav',
#        '/Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/blues/blues.00003.wav',
#        '/Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/blues/blues.00004.wav',
#        '/Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/blues/blues.00005.wav',
#        '/Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/blues/blues.00006.wav',
#        '/Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/blues/blues.00007.wav',
#        '/Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/blues/blues.00008.wav',
#        '/Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/blues/blues.00009.wav',
#        '/Users/stephen/Flatiron/Phase4/MIR/Data/genres_original/blues/blues.00010.wav',
# ...

# %%
# numerical class ID 

genre_id = {
    'blues': 0, 
    'classical': 1, 
    'country': 2, 
    'disco': 3, 
    'hiphop': 4, 
    'jazz': 5, 
    'metal': 6, 
    'pop': 7, 
    'reggae': 8, 
    'rock': 9
}

# %%
class SoundDS(Dataset):
    def __init__(self, df, data_path):
        self.df = df
        self.data_path = str(data_path)


    def __len__(self):
        return len(self.df)
